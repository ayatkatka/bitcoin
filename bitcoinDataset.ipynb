# %% [markdown]
# <a href="https://colab.research.google.com/github/ayatkatka/bitcoin/blob/main/bitcoinDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **هنا تم تعريف قاعده البينات التي تم اختيارها للمشروع و تم استخدام اكواد لفهم البيانات اكر **

# %%
import pandas as pd
df=pd.read_csv('bitcoinDataset.csv')
print(df)
print(df.info())
print(df.shape)
print(df.describe())
print(df.head())
print(df.tail())
print(df.duplicated())
print(df.isnull())
print(df.dropna())
print(df.corr)
print(df.dtypes)
print(df.loc[0:9, ['Date','Closing Price (USD)']])
# Out:
#             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     06/09/2023      25772.601560      25845.994140     25708.595700
# 1     05/09/2023      25814.957030      25858.375000     25589.988280
# 2     04/09/2023      25968.169920      26081.525390     25657.025390
# 3     03/09/2023      25869.472660      26087.148440     25817.031250
# 4     02/09/2023      25800.910160      25970.285160     25753.093750
# ...          ...               ...               ...              ...
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0            25721.945310                  25721.945310    1.025276e+10
# 1            25779.982420                  25779.982420    1.109474e+10
# 2            25812.416020                  25812.416020    1.068064e+10
# 3            25969.566410                  25969.566410    8.962525e+09
# 4            25868.798830                  25868.798830    1.010039e+10
# ...                   ...                           ...             ...
# 3166           274.473999                    274.473999    4.396280e+07
# 3167           264.195007                    264.195007    5.562910e+07
# 3168           281.082001                    281.082001    3.305440e+07
# 3169           315.032013                    315.032013    7.860650e+06
# 3170           314.248993                    314.248993    8.036550e+06
#
# [3171 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3171 entries, 0 to 3170
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          3171 non-null   object
#  1   Open Price (USD)              3171 non-null   float64
#  2   High Price (USD)              3171 non-null   float64
#  3   Low Price (USD)               3171 non-null   float64
#  4   Closing Price (USD)           3171 non-null   float64
#  5   Adjusted Closing Price (USD)  3171 non-null   float64
#  6   Trading Volume                3171 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 173.5+ KB
# None
# (3171, 7)
#        Open Price (USD)  High Price (USD)  Low Price (USD)  \
# count       3171.000000       3171.000000      3171.000000
# mean       14332.172768      14674.383308     13956.292591
# std        16065.029720      16460.429204     15612.281509
# min          176.897003        211.731003       171.509995
# 25%         1068.204956       1110.829956      1043.929993
# 50%         8221.580078       8371.150391      8005.310059
# 75%        22287.365235      22661.470700     21625.421875
# max        67549.734380      68789.625000     66382.062500
#
#        Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# count          3171.000000                   3171.000000    3.171000e+03
# mean          14338.795762                  14338.795762    1.706365e+10
# std           16061.184736                  16061.184736    1.943969e+10
# min             178.102997                    178.102997    7.860650e+06
# 25%            1075.885010                   1075.885010    2.564590e+08
# 50%            8222.078125                   8222.078125    1.217532e+10
# 75%           22358.014650                  22358.014650    2.787545e+10
# max           67566.828130                  67566.828130    3.510000e+11
#          Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0  06/09/2023       25772.60156       25845.99414      25708.59570
# 1  05/09/2023       25814.95703       25858.37500      25589.98828
# 2  04/09/2023       25968.16992       26081.52539      25657.02539
# 3  03/09/2023       25869.47266       26087.14844      25817.03125
# 4  02/09/2023       25800.91016       25970.28516      25753.09375
#
#    Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0          25721.94531                   25721.94531    1.025276e+10
# 1          25779.98242                   25779.98242    1.109474e+10
# 2          25812.41602                   25812.41602    1.068064e+10
# 3          25969.56641                   25969.56641    8.962525e+09
# 4          25868.79883                   25868.79883    1.010039e+10
#             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 3166           274.473999                    274.473999      43962800.0
# 3167           264.195007                    264.195007      55629100.0
# 3168           281.082001                    281.082001      33054400.0
# 3169           315.032013                    315.032013       7860650.0
# 3170           314.248993                    314.248993       8036550.0
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3166    False
# 3167    False
# 3168    False
# 3169    False
# 3170    False
# Length: 3171, dtype: bool
#        Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     False             False             False            False
# 1     False             False             False            False
# 2     False             False             False            False
# 3     False             False             False            False
# 4     False             False             False            False
# ...     ...               ...               ...              ...
# 3166  False             False             False            False
# 3167  False             False             False            False
# 3168  False             False             False            False
# 3169  False             False             False            False
# 3170  False             False             False            False
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0                   False                         False           False
# 1                   False                         False           False
# 2                   False                         False           False
# 3                   False                         False           False
# 4                   False                         False           False
# ...                   ...                           ...             ...
# 3166                False                         False           False
# 3167                False                         False           False
# 3168                False                         False           False
# 3169                False                         False           False
# 3170                False                         False           False
#
# [3171 rows x 7 columns]
#             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     06/09/2023      25772.601560      25845.994140     25708.595700
# 1     05/09/2023      25814.957030      25858.375000     25589.988280
# 2     04/09/2023      25968.169920      26081.525390     25657.025390
# 3     03/09/2023      25869.472660      26087.148440     25817.031250
# 4     02/09/2023      25800.910160      25970.285160     25753.093750
# ...          ...               ...               ...              ...
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0            25721.945310                  25721.945310    1.025276e+10
# 1            25779.982420                  25779.982420    1.109474e+10
# 2            25812.416020                  25812.416020    1.068064e+10
# 3            25969.566410                  25969.566410    8.962525e+09
# 4            25868.798830                  25868.798830    1.010039e+10
# ...                   ...                           ...             ...
# 3166           274.473999                    274.473999    4.396280e+07
# 3167           264.195007                    264.195007    5.562910e+07
# 3168           281.082001                    281.082001    3.305440e+07
# 3169           315.032013                    315.032013    7.860650e+06
# 3170           314.248993                    314.248993    8.036550e+06
#
# [3171 rows x 7 columns]
# <bound method DataFrame.corr of             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     06/09/2023      25772.601560      25845.994140     25708.595700
# 1     05/09/2023      25814.957030      25858.375000     25589.988280
# 2     04/09/2023      25968.169920      26081.525390     25657.025390
# 3     03/09/2023      25869.472660      26087.148440     25817.031250
# 4     02/09/2023      25800.910160      25970.285160     25753.093750
# ...          ...               ...               ...              ...
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0            25721.945310                  25721.945310    1.025276e+10
# 1            25779.982420                  25779.982420    1.109474e+10
# 2            25812.416020                  25812.416020    1.068064e+10
# 3            25969.566410                  25969.566410    8.962525e+09
# 4            25868.798830                  25868.798830    1.010039e+10
# ...                   ...                           ...             ...
# 3166           274.473999                    274.473999    4.396280e+07
# 3167           264.195007                    264.195007    5.562910e+07
# 3168           281.082001                    281.082001    3.305440e+07
# 3169           315.032013                    315.032013    7.860650e+06
# 3170           314.248993                    314.248993    8.036550e+06
#
# [3171 rows x 7 columns]>
# Date                             object
# Open Price (USD)                float64
# High Price (USD)                float64
# Low Price (USD)                 float64
# Closing Price (USD)             float64
# Adjusted Closing Price (USD)    float64
# Trading Volume                  float64
# dtype: object
#          Date  Closing Price (USD)
# 0  06/09/2023          25721.94531
# 1  05/09/2023          25779.98242
# 2  04/09/2023          25812.41602
# 3  03/09/2023          25969.56641
# 4  02/09/2023          25868.79883
# 5  01/09/2023          25800.72461
# 6  31/08/2023          25931.47266
# 7  30/08/2023          27297.26563
# 8  29/08/2023          27727.39258
# 9  28/08/2023          26106.15039

# %% [markdown]
# هنا تم اضافه اوتلاير

# %%
# Exclude the 'Date' column when performing numerical comparisons for outlier detection
numerical_columns = bitcoin_df.select_dtypes(include=['float64', 'int64']).columns
Q1 = bitcoin_df[numerical_columns].quantile(0.25)
Q3 = bitcoin_df[numerical_columns].quantile(0.75)
IQR = Q3 - Q1
outliers = ((bitcoin_df[numerical_columns] < (Q1 - 1.5 * IQR)) | (bitcoin_df[numerical_columns] > (Q3 + 1.5 * IQR))).any()

# Output the results
print('Outliers detected:\n', outliers)
# Out:
# Outliers detected:
#  Open Price (USD)                True
# High Price (USD)                True
# Low Price (USD)                 True
# Closing Price (USD)             True
# Adjusted Closing Price (USD)    True
# Trading Volume                  True
# dtype: bool

# %% [markdown]
# هنا تم مقارنه بين trading volume and adj closing عن طريق سكاتار تشارت

# %%
from sklearn import svm
X = [[0, 0], [2, 2]]
y = [0.5, 2.5]
regr = svm.SVR()
regr.fit(X, y)
regr.predict([[1, 1]])
# Out:
# array([1.5])

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("bitcoinDataset.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-0de83fd609f6> in <cell line: 1>()
# ----> 1 df["Date"]=pd.to_datetime(df["Date"])
#       2 df["day"]=(df["date"]).dt.day
#       3 df["month"]=(df["date"]).dt.month
#       4 df["year"]=(df["date"]).dt.year
#       5 df["time"]=(df["date"]).dt.time
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048             result = arg.map(cache_array)
#    1049         else:
# -> 1050             values = convert_listlike(arg._values, format)
#    1051             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452     if format is not None and format != "mixed":
# --> 453         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     454
#     455     result, tz_parsed = objects_to_datetime64ns(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "31/08/2023" doesn't match format "%m/%d/%Y", at position 6. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df
# Out:
#             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     06/09/2023      25772.601560      25845.994140     25708.595700
# 1     05/09/2023      25814.957030      25858.375000     25589.988280
# 2     04/09/2023      25968.169920      26081.525390     25657.025390
# 3     03/09/2023      25869.472660      26087.148440     25817.031250
# 4     02/09/2023      25800.910160      25970.285160     25753.093750
# ...          ...               ...               ...              ...
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0            25721.945310                  25721.945310    1.025276e+10
# 1            25779.982420                  25779.982420    1.109474e+10
# 2            25812.416020                  25812.416020    1.068064e+10
# 3            25969.566410                  25969.566410    8.962525e+09
# 4            25868.798830                  25868.798830    1.010039e+10
# ...                   ...                           ...             ...
# 3166           274.473999                    274.473999    4.396280e+07
# 3167           264.195007                    264.195007    5.562910e+07
# 3168           281.082001                    281.082001    3.305440e+07
# 3169           315.032013                    315.032013    7.860650e+06
# 3170           314.248993                    314.248993    8.036550e+06
#
# [3171 rows x 7 columns]

# %%
df=df.set_index("Date")

# %%
close=df[["Closing Price (USD)"]]

# %%
close.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df=pd.read_csv("bitcoinDataset.csv")

# %%
data.corr()
# Out:
#                               Open Price (USD)  High Price (USD)  \
# Open Price (USD)                      1.000000          0.999487
# High Price (USD)                      0.999487          1.000000
# Low Price (USD)                       0.999078          0.998942
# Adjusted Closing Price (USD)          0.998770          0.999446
# Trading Volume                        0.688368          0.693274
# Price Change                          0.024360          0.024971
#
#                               Low Price (USD)  Adjusted Closing Price (USD)  \
# Open Price (USD)                     0.999078                      0.998770
# High Price (USD)                     0.998942                      0.999446
# Low Price (USD)                      1.000000                      0.999346
# Adjusted Closing Price (USD)         0.999346                      1.000000
# Trading Volume                       0.679064                      0.687070
# Price Change                         0.026449                      0.025571
#
#                               Trading Volume  Price Change
# Open Price (USD)                    0.688368      0.024360
# High Price (USD)                    0.693274      0.024971
# Low Price (USD)                     0.679064      0.026449
# Adjusted Closing Price (USD)        0.687070      0.025571
# Trading Volume                      1.000000     -0.003677
# Price Change                       -0.003677      1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bitcoinDataset.csv')
df.isnull()
Df=df.dropna()
mean1=df['Closing Price (USD)'].mean()
new_df=df.fillna(mean1, inplace=True)
df.plot(kind = 'scatter', x = 'Date', y = 'Trading Volume')
plt.show()

# %% [markdown]
# هنا تم اخراج العلاقه بين سعر بشكل عام بين كل الكولومز

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)

plt.plot(data['Date'], data['Closing Price (USD)'])  # Plot Date vs. Close

plt.title('Bitcoin Price Over Time')  # Set the chart title
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Closing Price (USD)')  # Set the y-axis label

plt.grid(True)  # Add a grid for better readability

plt.xticks(rotation=45)  # Rotate x-axis labels for better spacing

plt.tight_layout()  # Ensure proper spacing of elements

plt.show()  # Display the chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-14fa2c2c6962> in <cell line: 5>()
#       3 plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)
#       4
# ----> 5 plt.plot(data['Date'], data['Closing Price (USD)'])  # Plot Date vs. Close
#       6
#       7 plt.title('Bitcoin Price Over Time')  # Set the chart title
#
# NameError: name 'data' is not defined

# %%
sns.relplot(x="Date",y="High Price (USD)",data=data,kind="scatter",size="Low Price (USD)",hue="Low Price (USD)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a5c6117f8377> in <cell line: 1>()
# ----> 1 sns.relplot(x="Date",y="High Price (USD)",data=data,kind="scatter",size="Low Price (USD)",hue="Low Price (USD)")
#       2
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
df=pd.read_csv('bitcoinDataset.csv')
print(df)
print(df.corr())
# Out:
#             Date  Open Price (USD)  High Price (USD)  Low Price (USD)  \
# 0     06/09/2023      25772.601560      25845.994140     25708.595700
# 1     05/09/2023      25814.957030      25858.375000     25589.988280
# 2     04/09/2023      25968.169920      26081.525390     25657.025390
# 3     03/09/2023      25869.472660      26087.148440     25817.031250
# 4     02/09/2023      25800.910160      25970.285160     25753.093750
# ...          ...               ...               ...              ...
# 3166  05/01/2015        265.084015        278.341003       265.084015
# 3167  04/01/2015        281.145996        287.230011       257.612000
# 3168  03/01/2015        314.846008        315.149994       281.082001
# 3169  02/01/2015        314.079010        315.838989       313.565002
# 3170  01/01/2015        320.434998        320.434998       314.002991
#
#       Closing Price (USD)  Adjusted Closing Price (USD)  Trading Volume
# 0            25721.945310                  25721.945310    1.025276e+10
# 1            25779.982420                  25779.982420    1.109474e+10
# 2            25812.416020                  25812.416020    1.068064e+10
# 3            25969.566410                  25969.566410    8.962525e+09
# 4            25868.798830                  25868.798830    1.010039e+10
# ...                   ...                           ...             ...
# 3166           274.473999                    274.473999    4.396280e+07
# 3167           264.195007                    264.195007    5.562910e+07
# 3168           281.082001                    281.082001    3.305440e+07
# 3169           315.032013                    315.032013    7.860650e+06
# 3170           314.248993                    314.248993    8.036550e+06
#
# [3171 rows x 7 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-2fd15e1fe814> in <cell line: 4>()
#       2 df=pd.read_csv('bitcoinDataset.csv')
#       3 print(df)
# ----> 4 print(df.corr())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1730                 arr.flags.writeable = False
#    1731         else:
# -> 1732             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733             # The underlying data was copied within _interleave, so no need
#    1734             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1792             else:
#    1793                 arr = blk.get_values(dtype)
# -> 1794             result[rl.indexer] = arr
#    1795             itemmask[rl.indexer] = 1
#    1796
#
# ValueError: could not convert string to float: '06/09/2023'

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif

# Load the dataset
data = pd.read_csv("bitcoinDataset.csv")

# Define the target variable
target = "Closing Price (USD)"

# Select the features to evaluate
features = ["Open Price (USD)", "High Price (USD)", "Low Price (USD)", "Trading Volume"]

# Calculate the Gain Ratio for each feature
gain_ratios = mutual_info_classif(data[features], data[target], discrete_features=True)

# Print the Gain Ratio for each feature
for feature, gain_ratio in zip(features, gain_ratios):
    print(f"{feature}: {gain_ratio}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1e1ca15438d5> in <cell line: 14>()
#      12
#      13 # Calculate the Gain Ratio for each feature
# ---> 14 gain_ratios = mutual_info_classif(data[features], data[target], discrete_features=True)
#      15
#      16 # Print the Gain Ratio for each feature
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_mutual_info.py in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     465            of a Random Vector:, Probl. Peredachi Inf., 23:2 (1987), 9-16
#     466     """
# --> 467     check_classification_targets(y)
#     468     return _estimate_mi(X, y, discrete_features, True, n_neighbors, copy, random_state)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'continuous'

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('bitcoinDataset.csv')

df['Closing Price Category'] = pd.qcut(df['Closing Price (USD)'], 3, labels=['Low', 'Medium', 'High'])

le = LabelEncoder()
df['Closing Price Category Encoded'] = le.fit_transform(df['Closing Price Category'])

y = df['Closing Price Category Encoded']

mi = mutual_info_classif(df[['Closing Price (USD)']], y, discrete_features=False)

print('Mutual Information:', mi[0])

import numpy as np
entropy_y = -np.sum([p * np.log2(p) for p in np.bincount(y) / len(y) if p > 0])

print('Entropy of Target:', entropy_y)

gain_ratio = mi[0] / entropy_y
print('Gain Ratio:', gain_ratio)
# Out:
# Mutual Information: 1.097883652891662
# Entropy of Target: 1.584962500721156
# Gain Ratio: 0.6926874625690679

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Time Series Line Chart
plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)

plt.plot(data['Date'], data['Closing Price (USD)'], marker='o', linestyle='-')  # Plot Date vs. Close

plt.title('Bitcoin Price Over Time')  # Set the chart title
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Price (USD)')  # Set the y-axis label

plt.grid(True)  # Add a grid for better readability

plt.xticks(rotation=45)  # Rotate x-axis labels for better spacing

plt.tight_layout()  # Ensure proper spacing of elements

plt.show()

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import LabelEncoder

# Load the dataset
bitcoin_df = pd.read_csv('bitcoinDataset.csv')

# Encode the target variable
le = LabelEncoder()
bitcoin_df['Closing Price (USD)'] = le.fit_transform(bitcoin_df['Closing Price (USD)'])

# Select numeric features and target variable
numeric_cols = bitcoin_df.select_dtypes(include=['float64', 'int64']).columns
X = bitcoin_df[numeric_cols].drop(['Closing Price (USD)'], axis=1)
y = bitcoin_df['Closing Price (USD)']

# Calculate Mutual Information
mutual_info = mutual_info_classif(X, y)

# Create a DataFrame to display Mutual Information for each feature
mi_df = pd.DataFrame(mutual_info, index=X.columns, columns=['Mutual Information'])
mi_df.sort_values(by='Mutual Information', ascending=False, inplace=True)

print(mi_df)
# Out:
#                               Mutual Information
# High Price (USD)                        0.950000
# Low Price (USD)                         0.950000
# Adjusted Closing Price (USD)            0.616667
# Open Price (USD)                        0.283333
# Trading Volume                          0.283333

# %% [markdown]
# هنا تم اخراج العلاقه بين سعر
# open and closing

# %%
import pandas as pd

file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

corr = bitcoin_df['Date'], (bitcoin_df['Trading Volume'])

print('Correlation between Open and  Closing Price (USD):', corr)
# Out:
# Correlation between Open and  Closing Price (USD): (0       06/09/2023
# 1       05/09/2023
# 2       04/09/2023
# 3       03/09/2023
# 4       02/09/2023
#            ...
# 3166    05/01/2015
# 3167    04/01/2015
# 3168    03/01/2015
# 3169    02/01/2015
# 3170    01/01/2015
# Name: Date, Length: 3171, dtype: object, 0       1.025276e+10
# 1       1.109474e+10
# 2       1.068064e+10
# 3       8.962525e+09
# 4       1.010039e+10
#             ...
# 3166    4.396280e+07
# 3167    5.562910e+07
# 3168    3.305440e+07
# 3169    7.860650e+06
# 3170    8.036550e+06
# Name: Trading Volume, Length: 3171, dtype: float64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(x="Date",y="Adjusted Closing Price (USD)",data=data, marker=True,color='b')
plt.grid(True)  # Add a grid for better readability

plt.xticks(rotation=45)  # Rotate x-axis labels for better spacing

plt.tight_layout()  # Ensure proper spacing of elements

plt.show()

# %%
sns.relplot(x="Date",y="Closing Price (USD)",data=data,kind="scatter",size="Low Price (USD)",hue="Low Price (USD)")
plt.show()

# %% [markdown]
# هنا تم اخراج العلاقه بين سعر
# high and low

# %%
diff=data["Open Price (USD)"]-data["Closing Price (USD)"]

# %%
diff
# Out:
# 0        50.656250
# 1        34.974610
# 2       155.753900
# 3      -100.093750
# 4       -67.888670
#            ...
# 3166     -9.389984
# 3167     16.950989
# 3168     33.764007
# 3169     -0.953003
# 3170      6.186005
# Length: 3171, dtype: float64

# %%
sns.lineplot(x=data["Date"],y=diff.values,markers="o")
plt.title("Difference in Open & Close Price")
plt.xlabel("Year")
plt.ylabel("Difference in Opening and Closing Price")
plt.show()

# %%
diff=data["High Price (USD)"]-data["Low Price (USD)"]

# %%
sns.lineplot(x=data["Date"],y=diff.values,markers="o",color="r")
plt.title("Difference in High & Low Price")
plt.xlabel("Year")
plt.ylabel("High and Low ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-c98df34c7a37> in <cell line: 1>()
# ----> 1 sns.lineplot(x=data["Date"],y=diff.values,markers="o",color="r")
#       2 plt.title("Difference in High & Low Price")
#       3 plt.xlabel("Year")
#       4 plt.ylabel("High and Low ")
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
import pandas as pd

file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

corr = bitcoin_df['High Price (USD)'].corr(bitcoin_df['Low Price (USD)'])

print('Correlation between High and  Low Price (USD):', corr)
# Out:
# Correlation between High and  Low Price (USD): 0.998941558724401

# %%
data['Price Change'] = data['Closing Price (USD)'].diff()

# Create a Price Change Distribution Histogram
plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)

plt.hist(data['Price Change'].dropna(), bins=20, color='b', alpha=0.7)  # Plot the histogram

plt.title('Price Change Distribution')
plt.xlabel('Price Change (USD)')
plt.ylabel('Frequency')

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
sns.lineplot(x="Date",y="Closing Price (USD)",data=data, marker=True,color='b')
plt.grid(True)  # Add a grid for better readability

plt.xticks(rotation=45)  # Rotate x-axis labels for better spacing

plt.tight_layout()  # Ensure proper spacing of elements

plt.show()

# %%
diff=data["High Price (USD)"]-data["Low Price (USD)"]

# %%
sns.lineplot(x=data["Date"],y=diff.values,markers="o",color="r")
plt.title("Difference in High & Low Price")
plt.xlabel("Year")
plt.ylabel("High and Low ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-c98df34c7a37> in <cell line: 1>()
# ----> 1 sns.lineplot(x=data["Date"],y=diff.values,markers="o",color="r")
#       2 plt.title("Difference in High & Low Price")
#       3 plt.xlabel("Year")
#       4 plt.ylabel("High and Low ")
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
data.set_index("Date",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-489645549ee6> in <cell line: 1>()
# ----> 1 data.set_index("Date",inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
average_price_by_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-911ff4bcc99b> in <cell line: 1>()
# ----> 1 average_price_by_year
#
# NameError: name 'average_price_by_year' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

bitcoin_df['Date'] = pd.to_datetime(bitcoin_df['Date'], format='%d/%m/%Y')

bitcoin_df.sort_values('Closing Price (USD)', inplace=True)

plt.figure(figsize=(14, 7))
plt.bar(bitcoin_df['Date'], bitcoin_df['Closing Price (USD)'], label='Closing Price (USD)', color='black')
plt.title('Bitcoin Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

bitcoin_df['Date'] = pd.to_datetime(bitcoin_df['Date'], format='%d/%m/%Y')

bitcoin_df.sort_values('Date', inplace=True)

plt.plot(bitcoin_df['Date'], bitcoin_df['High Price (USD)'], label='High Price (USD)', color='red')
plt.plot(bitcoin_df['Date'], bitcoin_df['Low Price (USD)'], label='Low Price (USD)', color='green')
plt.title('Bitcoin High and Low Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

bitcoin_df['Date'] = pd.to_datetime(bitcoin_df['Date'], format='%d/%m/%Y')

bitcoin_df.sort_values('Date', inplace=True)

plt.plot(bitcoin_df['Date'], bitcoin_df['Open Price (USD)'], label='Open Price (USD)', color='red')
plt.plot(bitcoin_df['Date'], bitcoin_df['Closing Price (USD)'], label='Closing Price (USD)', color='green')
plt.title('Bitcoin Open and Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

X = bitcoin_df[['Closing Price (USD)']]
y = bitcoin_df['Adjusted Closing Price (USD)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

print('Coefficients:', regr.coef_)
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
print('mean_absolute_error: %.2f' % mean_absolute_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
print('percentage error: %.2f' % mean_absolute_percentage_error

(y_test, y_pred))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients: [1.]
# Mean squared error: 0.00
# mean_absolute_error: 0.00
# Coefficient of determination: 1.00
# percentage error: 0.00

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

X = bitcoin_df[['Closing Price (USD)']]
y = bitcoin_df['Trading Volume']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

print('Coefficients:', regr.coef_)
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
print('mean_absolute_error: %.2f' % mean_absolute_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
print('percentage error: %.2f' % mean_absolute_percentage_error

(y_test, y_pred))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients: [858376.31865137]
# Mean squared error: 185949111389706190848.00
# mean_absolute_error: 9797145799.40
# Coefficient of determination: 0.49
# percentage error: 36.68

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

X = bitcoin_df[['Closing Price (USD)']]
y = bitcoin_df['Open Price (USD)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

print('Coefficients:', regr.coef_)
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
print('mean_absolute_error: %.2f' % mean_absolute_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
print('percentage error: %.2f' % mean_absolute_percentage_error

(y_test, y_pred))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients: [0.99730511]
# Mean squared error: 722164.57
# mean_absolute_error: 398.36
# Coefficient of determination: 1.00
# percentage error: 0.03

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

X = bitcoin_df[['Closing Price (USD)']]
y = bitcoin_df['High Price (USD)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

print('Coefficients:', regr.coef_)
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
print('mean_absolute_error: %.2f' % mean_absolute_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
print('percentage error: %.2f' % mean_absolute_percentage_error

(y_test, y_pred))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients: [1.02371412]
# Mean squared error: 409532.17
# mean_absolute_error: 289.31
# Coefficient of determination: 1.00
# percentage error: 0.02

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


file_path = 'bitcoinDataset.csv'
bitcoin_df = pd.read_csv(file_path)

X = bitcoin_df[['Closing Price (USD)']]
y = bitcoin_df['Low Price (USD)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

print('Coefficients:', regr.coef_)
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
print('mean_absolute_error: %.2f' % mean_absolute_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
print('percentage error: %.2f' % mean_absolute_percentage_error

(y_test, y_pred))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients: [0.97048351]
# Mean squared error: 359922.37
# mean_absolute_error: 299.21
# Coefficient of determination: 1.00
# percentage error: 0.04

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
X = np.arange(6).reshape(3, 2)
X



poly = PolynomialFeatures(2)
poly.fit_transform(X)



poly = PolynomialFeatures(interaction_only=True)
poly.fit_transform(X)
# Out:
# array([[ 1.,  0.,  1.,  0.],
#        [ 1.,  2.,  3.,  6.],
#        [ 1.,  4.,  5., 20.]])

# %%
from sklearn.svm import SVR
import numpy as np
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))
# Fit regression model
svr = SVR().fit(X, y)
# Predict
X_test = np.arange(0.0, 5.0, 1)[:, np.newaxis]
svr.predict(X_test)
# Out:
# array([-0.07840308,  0.78077042,  0.81326895,  0.08638149, -0.6928019 ])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X, y = make_regression(n_features=4, n_informative=2, random_state=0, shuffle=False)
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X, y)
print(rfr.predict([[0, 1, 0, 1]]))
# Out:
# [32.8996978]

# %%
from matplotlib import pyplot as plt
_df_0['Closing Price (USD)'].plot(kind='hist', bins=20, title='Closing Price (USD)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Low Price (USD)'].plot(kind='hist', bins=20, title='Low Price (USD)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Trading Volume'].plot(kind='hist', bins=20, title='Trading Volume')
plt.gca().spines[['top', 'right',]].set_visible(False)
